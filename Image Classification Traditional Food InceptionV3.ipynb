# %%
import os
import numpy as np
import shutil
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications.inception_v3 import InceptionV3
from keras_preprocessing import image
from tensorflow.keras.applications.xception import preprocess_input
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
print('TensorFlow :', tf.__version__)
# Out:
# TensorFlow : 2.8.0

# %%
dataset = os.path.join(r'E:\project plan\indonesian food', '')

for dir in os.listdir(dataset):
  class_dir = os.path.join(dataset, dir)
  print('total images for', dir, 'is', len(os.listdir(class_dir)))
# Out:
# total images for Ayam Betutu is 211
# total images for Bika Ambon is 212
# total images for Empek-Empek is 212
# total images for Gudeg is 220
# total images for Gulai Ikan Patin is 200
# total images for Kue Serabi is 200
# total images for Lumpia is 223
# total images for Mie Aceh is 210
# total images for Rendang is 220
# total images for Soto Banjar is 180

# %%
root_dir = 'E:/project plan/indonesian food/' 
classes_dir = os.listdir(root_dir)

train_ratio = 0.8
val_ratio  = 0.1

for cls in classes_dir:
    os.makedirs(root_dir +'train_dir/' + cls, exist_ok=True)
    os.makedirs(root_dir +'test_dir/' + cls, exist_ok=True)
    os.makedirs(root_dir +'val_dir/' + cls, exist_ok=True)
    
    src = root_dir + cls
    FileNames = os.listdir(src)

    np.random.shuffle(FileNames)
    train_FileNames, test_FileNames, val_FileNames = np.split(np.array(FileNames),
                                                              [int(train_ratio * len(FileNames)), 
                                                               int((1-val_ratio) * len(FileNames))])

    train_FileNames = [src+'/'+ name  for name in train_FileNames.tolist()]
    test_FileNames  = [src+'/' + name for name in test_FileNames.tolist()]
    val_FileNames   = [src+'/' + name for name in val_FileNames.tolist()]
    print("\n Total images: ",cls, len(FileNames),
          '\n Training: ', len(train_FileNames),
          '\n Testing: ', len(test_FileNames),
          '\n Validation: ', len(val_FileNames))
    
    for name in train_FileNames:
      shutil.copy(name, root_dir +'train_dir/' + cls)
    for name in test_FileNames:
      shutil.copy(name, root_dir +'test_dir/' + cls)
    for name in val_FileNames:
      shutil.copy(name, root_dir +'val_dir/' + cls)
# Out:
#  Total images:  Ayam Betutu 211
#  Training:  168
#  Testing:  21
#  Validation:  22
#
#  Total images:  Bika Ambon 212
#  Training:  169
#  Testing:  21
#  Validation:  22
#
#  Total images:  Empek-Empek 212
#  Training:  169
#  Testing:  21
#  Validation:  22
#
#  Total images:  Gudeg 220
#  Training:  176
#  Testing:  22
#  Validation:  22
#
#  Total images:  Gulai Ikan Patin 200
#  Training:  160
#  Testing:  20
#  Validation:  20
#
#  Total images:  Kue Serabi 200
#  Training:  160
#  Testing:  20
#  Validation:  20
#
#  Total images:  Lumpia 223
#  Training:  178
#  Testing:  22
#  Validation:  23
#
#  Total images:  Mie Aceh 210
#  Training:  168
#  Testing:  21
#  Validation:  21
#
#  Total images:  Rendang 220
#  Training:  176
#  Testing:  22
#  Validation:  22
#
#  Total images:  Soto Banjar 180
#  Training:  144
#  Testing:  18
#  Validation:  18

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = "E:/project plan/indonesian food/train_dir"
val_dir = "E:/project plan/indonesian food/val_dir"
test_dir = "E:/project plan/indonesian food/test_dir"

train_datagen = ImageDataGenerator(rescale = 1./255
                                   )

test_datagen  = ImageDataGenerator(rescale = 1.0/255
                                   )

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=20,
                                                    class_mode='categorical',
                                                    target_size=(75,75))     

validation_generator =  test_datagen.flow_from_directory(val_dir,
                                                         batch_size=20,
                                                         class_mode  = 'categorical',
                                                         target_size=(75,75))
# Out:
# Found 1668 images belonging to 10 classes.
# Found 212 images belonging to 10 classes.

# %%
pretrained_model = InceptionV3(input_shape = (75,75, 3),
                                include_top = False,
                                weights = 'imagenet')

for layer in pretrained_model.layers:
    layer.trainable = False
    
last_layer = pretrained_model.get_layer('mixed5')
print('last layer output shape: ', last_layer.output_shape)
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 3, 3, 768)

# %%
x = layers.Flatten()(last_output)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(10, activation='softmax')(x)

# %%
model_2 = Model(pretrained_model.input, x)
model_2.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 75, 75, 3)]  0           []
#
#  conv2d_282 (Conv2D)            (None, 37, 37, 32)   864         ['input_4[0][0]']
#
#  batch_normalization_282 (Batch  (None, 37, 37, 32)  96          ['conv2d_282[0][0]']
#  Normalization)
#
#  activation_282 (Activation)    (None, 37, 37, 32)   0           ['batch_normalization_282[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_282[0][0]']
#
#  batch_normalization_283 (Batch  (None, 35, 35, 32)  96          ['conv2d_283[0][0]']
#  Normalization)
#
#  activation_283 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_283[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 35, 35, 64)   18432       ['activation_283[0][0]']
#
#  batch_normalization_284 (Batch  (None, 35, 35, 64)  192         ['conv2d_284[0][0]']
#  Normalization)
#
#  activation_284 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_284[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 17, 17, 64)  0           ['activation_284[0][0]']
#  )
#
#  conv2d_285 (Conv2D)            (None, 17, 17, 80)   5120        ['max_pooling2d_12[0][0]']
#
#  batch_normalization_285 (Batch  (None, 17, 17, 80)  240         ['conv2d_285[0][0]']
#  Normalization)
#
#  activation_285 (Activation)    (None, 17, 17, 80)   0           ['batch_normalization_285[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 15, 15, 192)  138240      ['activation_285[0][0]']
#
#  batch_normalization_286 (Batch  (None, 15, 15, 192)  576        ['conv2d_286[0][0]']
#  Normalization)
#
#  activation_286 (Activation)    (None, 15, 15, 192)  0           ['batch_normalization_286[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 7, 7, 192)   0           ['activation_286[0][0]']
#  )
#
#  conv2d_290 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_13[0][0]']
#
#  batch_normalization_290 (Batch  (None, 7, 7, 64)    192         ['conv2d_290[0][0]']
#  Normalization)
#
#  activation_290 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_290[0][0]']
#
#  conv2d_288 (Conv2D)            (None, 7, 7, 48)     9216        ['max_pooling2d_13[0][0]']
#
#  conv2d_291 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_290[0][0]']
#
#  batch_normalization_288 (Batch  (None, 7, 7, 48)    144         ['conv2d_288[0][0]']
#  Normalization)
#
#  batch_normalization_291 (Batch  (None, 7, 7, 96)    288         ['conv2d_291[0][0]']
#  Normalization)
#
#  activation_288 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_288[0][0]']
#
#  activation_291 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_291[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 7, 7, 192)   0           ['max_pooling2d_13[0][0]']
#  ooling2D)
#
#  conv2d_287 (Conv2D)            (None, 7, 7, 64)     12288       ['max_pooling2d_13[0][0]']
#
#  conv2d_289 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_288[0][0]']
#
#  conv2d_292 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_291[0][0]']
#
#  conv2d_293 (Conv2D)            (None, 7, 7, 32)     6144        ['average_pooling2d_27[0][0]']
#
#  batch_normalization_287 (Batch  (None, 7, 7, 64)    192         ['conv2d_287[0][0]']
#  Normalization)
#
#  batch_normalization_289 (Batch  (None, 7, 7, 64)    192         ['conv2d_289[0][0]']
#  Normalization)
#
#  batch_normalization_292 (Batch  (None, 7, 7, 96)    288         ['conv2d_292[0][0]']
#  Normalization)
#
#  batch_normalization_293 (Batch  (None, 7, 7, 32)    96          ['conv2d_293[0][0]']
#  Normalization)
#
#  activation_287 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_287[0][0]']
#
#  activation_289 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_289[0][0]']
#
#  activation_292 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_292[0][0]']
#
#  activation_293 (Activation)    (None, 7, 7, 32)     0           ['batch_normalization_293[0][0]']
#
#  mixed0 (Concatenate)           (None, 7, 7, 256)    0           ['activation_287[0][0]',
#                                                                   'activation_289[0][0]',
#                                                                   'activation_292[0][0]',
#                                                                   'activation_293[0][0]']
#
#  conv2d_297 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  batch_normalization_297 (Batch  (None, 7, 7, 64)    192         ['conv2d_297[0][0]']
#  Normalization)
#
#  activation_297 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_297[0][0]']
#
#  conv2d_295 (Conv2D)            (None, 7, 7, 48)     12288       ['mixed0[0][0]']
#
#  conv2d_298 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_297[0][0]']
#
#  batch_normalization_295 (Batch  (None, 7, 7, 48)    144         ['conv2d_295[0][0]']
#  Normalization)
#
#  batch_normalization_298 (Batch  (None, 7, 7, 96)    288         ['conv2d_298[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_295[0][0]']
#
#  activation_298 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_298[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 7, 7, 256)   0           ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_294 (Conv2D)            (None, 7, 7, 64)     16384       ['mixed0[0][0]']
#
#  conv2d_296 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_295[0][0]']
#
#  conv2d_299 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_298[0][0]']
#
#  conv2d_300 (Conv2D)            (None, 7, 7, 64)     16384       ['average_pooling2d_28[0][0]']
#
#  batch_normalization_294 (Batch  (None, 7, 7, 64)    192         ['conv2d_294[0][0]']
#  Normalization)
#
#  batch_normalization_296 (Batch  (None, 7, 7, 64)    192         ['conv2d_296[0][0]']
#  Normalization)
#
#  batch_normalization_299 (Batch  (None, 7, 7, 96)    288         ['conv2d_299[0][0]']
#  Normalization)
#
#  batch_normalization_300 (Batch  (None, 7, 7, 64)    192         ['conv2d_300[0][0]']
#  Normalization)
#
#  activation_294 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_294[0][0]']
#
#  activation_296 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_296[0][0]']
#
#  activation_299 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_299[0][0]']
#
#  activation_300 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_300[0][0]']
#
#  mixed1 (Concatenate)           (None, 7, 7, 288)    0           ['activation_294[0][0]',
#                                                                   'activation_296[0][0]',
#                                                                   'activation_299[0][0]',
#                                                                   'activation_300[0][0]']
#
#  conv2d_304 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  batch_normalization_304 (Batch  (None, 7, 7, 64)    192         ['conv2d_304[0][0]']
#  Normalization)
#
#  activation_304 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_304[0][0]']
#
#  conv2d_302 (Conv2D)            (None, 7, 7, 48)     13824       ['mixed1[0][0]']
#
#  conv2d_305 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_304[0][0]']
#
#  batch_normalization_302 (Batch  (None, 7, 7, 48)    144         ['conv2d_302[0][0]']
#  Normalization)
#
#  batch_normalization_305 (Batch  (None, 7, 7, 96)    288         ['conv2d_305[0][0]']
#  Normalization)
#
#  activation_302 (Activation)    (None, 7, 7, 48)     0           ['batch_normalization_302[0][0]']
#
#  activation_305 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_305[0][0]']
#
#  average_pooling2d_29 (AverageP  (None, 7, 7, 288)   0           ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_301 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed1[0][0]']
#
#  conv2d_303 (Conv2D)            (None, 7, 7, 64)     76800       ['activation_302[0][0]']
#
#  conv2d_306 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_305[0][0]']
#
#  conv2d_307 (Conv2D)            (None, 7, 7, 64)     18432       ['average_pooling2d_29[0][0]']
#
#  batch_normalization_301 (Batch  (None, 7, 7, 64)    192         ['conv2d_301[0][0]']
#  Normalization)
#
#  batch_normalization_303 (Batch  (None, 7, 7, 64)    192         ['conv2d_303[0][0]']
#  Normalization)
#
#  batch_normalization_306 (Batch  (None, 7, 7, 96)    288         ['conv2d_306[0][0]']
#  Normalization)
#
#  batch_normalization_307 (Batch  (None, 7, 7, 64)    192         ['conv2d_307[0][0]']
#  Normalization)
#
#  activation_301 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_301[0][0]']
#
#  activation_303 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_303[0][0]']
#
#  activation_306 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_306[0][0]']
#
#  activation_307 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_307[0][0]']
#
#  mixed2 (Concatenate)           (None, 7, 7, 288)    0           ['activation_301[0][0]',
#                                                                   'activation_303[0][0]',
#                                                                   'activation_306[0][0]',
#                                                                   'activation_307[0][0]']
#
#  conv2d_309 (Conv2D)            (None, 7, 7, 64)     18432       ['mixed2[0][0]']
#
#  batch_normalization_309 (Batch  (None, 7, 7, 64)    192         ['conv2d_309[0][0]']
#  Normalization)
#
#  activation_309 (Activation)    (None, 7, 7, 64)     0           ['batch_normalization_309[0][0]']
#
#  conv2d_310 (Conv2D)            (None, 7, 7, 96)     55296       ['activation_309[0][0]']
#
#  batch_normalization_310 (Batch  (None, 7, 7, 96)    288         ['conv2d_310[0][0]']
#  Normalization)
#
#  activation_310 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_310[0][0]']
#
#  conv2d_308 (Conv2D)            (None, 3, 3, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_311 (Conv2D)            (None, 3, 3, 96)     82944       ['activation_310[0][0]']
#
#  batch_normalization_308 (Batch  (None, 3, 3, 384)   1152        ['conv2d_308[0][0]']
#  Normalization)
#
#  batch_normalization_311 (Batch  (None, 3, 3, 96)    288         ['conv2d_311[0][0]']
#  Normalization)
#
#  activation_308 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_308[0][0]']
#
#  activation_311 (Activation)    (None, 3, 3, 96)     0           ['batch_normalization_311[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 3, 3, 288)   0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 3, 3, 768)    0           ['activation_308[0][0]',
#                                                                   'activation_311[0][0]',
#                                                                   'max_pooling2d_14[0][0]']
#
#  conv2d_316 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_316 (Batch  (None, 3, 3, 128)   384         ['conv2d_316[0][0]']
#  Normalization)
#
#  activation_316 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_316[0][0]']
#
#  conv2d_317 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_316[0][0]']
#
#  batch_normalization_317 (Batch  (None, 3, 3, 128)   384         ['conv2d_317[0][0]']
#  Normalization)
#
#  activation_317 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_317[0][0]']
#
#  conv2d_313 (Conv2D)            (None, 3, 3, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_318 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_317[0][0]']
#
#  batch_normalization_313 (Batch  (None, 3, 3, 128)   384         ['conv2d_313[0][0]']
#  Normalization)
#
#  batch_normalization_318 (Batch  (None, 3, 3, 128)   384         ['conv2d_318[0][0]']
#  Normalization)
#
#  activation_313 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_313[0][0]']
#
#  activation_318 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_318[0][0]']
#
#  conv2d_314 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_313[0][0]']
#
#  conv2d_319 (Conv2D)            (None, 3, 3, 128)    114688      ['activation_318[0][0]']
#
#  batch_normalization_314 (Batch  (None, 3, 3, 128)   384         ['conv2d_314[0][0]']
#  Normalization)
#
#  batch_normalization_319 (Batch  (None, 3, 3, 128)   384         ['conv2d_319[0][0]']
#  Normalization)
#
#  activation_314 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_314[0][0]']
#
#  activation_319 (Activation)    (None, 3, 3, 128)    0           ['batch_normalization_319[0][0]']
#
#  average_pooling2d_30 (AverageP  (None, 3, 3, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_312 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_315 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_314[0][0]']
#
#  conv2d_320 (Conv2D)            (None, 3, 3, 192)    172032      ['activation_319[0][0]']
#
#  conv2d_321 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_30[0][0]']
#
#  batch_normalization_312 (Batch  (None, 3, 3, 192)   576         ['conv2d_312[0][0]']
#  Normalization)
#
#  batch_normalization_315 (Batch  (None, 3, 3, 192)   576         ['conv2d_315[0][0]']
#  Normalization)
#
#  batch_normalization_320 (Batch  (None, 3, 3, 192)   576         ['conv2d_320[0][0]']
#  Normalization)
#
#  batch_normalization_321 (Batch  (None, 3, 3, 192)   576         ['conv2d_321[0][0]']
#  Normalization)
#
#  activation_312 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_312[0][0]']
#
#  activation_315 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_315[0][0]']
#
#  activation_320 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_320[0][0]']
#
#  activation_321 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_321[0][0]']
#
#  mixed4 (Concatenate)           (None, 3, 3, 768)    0           ['activation_312[0][0]',
#                                                                   'activation_315[0][0]',
#                                                                   'activation_320[0][0]',
#                                                                   'activation_321[0][0]']
#
#  conv2d_326 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#  batch_normalization_326 (Batch  (None, 3, 3, 160)   480         ['conv2d_326[0][0]']
#  Normalization)
#
#  activation_326 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_326[0][0]']
#
#  conv2d_327 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_326[0][0]']
#
#  batch_normalization_327 (Batch  (None, 3, 3, 160)   480         ['conv2d_327[0][0]']
#  Normalization)
#
#  activation_327 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_327[0][0]']
#
#  conv2d_323 (Conv2D)            (None, 3, 3, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_328 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_327[0][0]']
#
#  batch_normalization_323 (Batch  (None, 3, 3, 160)   480         ['conv2d_323[0][0]']
#  Normalization)
#
#  batch_normalization_328 (Batch  (None, 3, 3, 160)   480         ['conv2d_328[0][0]']
#  Normalization)
#
#  activation_323 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_323[0][0]']
#
#  activation_328 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_328[0][0]']
#
#  conv2d_324 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_323[0][0]']
#
#  conv2d_329 (Conv2D)            (None, 3, 3, 160)    179200      ['activation_328[0][0]']
#
#  batch_normalization_324 (Batch  (None, 3, 3, 160)   480         ['conv2d_324[0][0]']
#  Normalization)
#
#  batch_normalization_329 (Batch  (None, 3, 3, 160)   480         ['conv2d_329[0][0]']
#  Normalization)
#
#  activation_324 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_324[0][0]']
#
#  activation_329 (Activation)    (None, 3, 3, 160)    0           ['batch_normalization_329[0][0]']
#
#  average_pooling2d_31 (AverageP  (None, 3, 3, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_322 (Conv2D)            (None, 3, 3, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_325 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_324[0][0]']
#
#  conv2d_330 (Conv2D)            (None, 3, 3, 192)    215040      ['activation_329[0][0]']
#
#  conv2d_331 (Conv2D)            (None, 3, 3, 192)    147456      ['average_pooling2d_31[0][0]']
#
#  batch_normalization_322 (Batch  (None, 3, 3, 192)   576         ['conv2d_322[0][0]']
#  Normalization)
#
#  batch_normalization_325 (Batch  (None, 3, 3, 192)   576         ['conv2d_325[0][0]']
#  Normalization)
#
#  batch_normalization_330 (Batch  (None, 3, 3, 192)   576         ['conv2d_330[0][0]']
#  Normalization)
#
#  batch_normalization_331 (Batch  (None, 3, 3, 192)   576         ['conv2d_331[0][0]']
#  Normalization)
#
#  activation_322 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_322[0][0]']
#
#  activation_325 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_325[0][0]']
#
#  activation_330 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_330[0][0]']
#
#  activation_331 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_331[0][0]']
#
#  mixed5 (Concatenate)           (None, 3, 3, 768)    0           ['activation_322[0][0]',
#                                                                   'activation_325[0][0]',
#                                                                   'activation_330[0][0]',
#                                                                   'activation_331[0][0]']
#
#  flatten_5 (Flatten)            (None, 6912)         0           ['mixed5[0][0]']
#
#  dense_10 (Dense)               (None, 512)          3539456     ['flatten_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 512)          0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 10)           5130        ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 8,683,242
# Trainable params: 3,544,586
# Non-trainable params: 5,138,656
# __________________________________________________________________________________________________

# %%
model_2.compile(tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model_2.fit(train_generator,
                    validation_data=validation_generator,
                    steps_per_epoch=10,
                    validation_steps=3,
                    epochs=20,
                    verbose=1)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 9s 489ms/step - loss: 2.6457 - accuracy: 0.1755 - val_loss: 2.0982 - val_accuracy: 0.2667
# Epoch 2/20
# 10/10 [==============================] - 3s 340ms/step - loss: 2.1400 - accuracy: 0.2700 - val_loss: 1.7779 - val_accuracy: 0.3667
# Epoch 3/20
# 10/10 [==============================] - 3s 310ms/step - loss: 1.7961 - accuracy: 0.3800 - val_loss: 1.4315 - val_accuracy: 0.5667
# Epoch 4/20
# 10/10 [==============================] - 3s 317ms/step - loss: 1.5105 - accuracy: 0.5250 - val_loss: 1.3557 - val_accuracy: 0.5000
# Epoch 5/20
# 10/10 [==============================] - 3s 311ms/step - loss: 1.3863 - accuracy: 0.5638 - val_loss: 1.2929 - val_accuracy: 0.6167
# Epoch 6/20
# 10/10 [==============================] - 3s 313ms/step - loss: 1.1895 - accuracy: 0.6011 - val_loss: 1.4059 - val_accuracy: 0.4500
# Epoch 7/20
# 10/10 [==============================] - 4s 426ms/step - loss: 1.1770 - accuracy: 0.6150 - val_loss: 1.3311 - val_accuracy: 0.5167
# Epoch 8/20
# 10/10 [==============================] - 4s 400ms/step - loss: 1.0472 - accuracy: 0.6750 - val_loss: 1.1094 - val_accuracy: 0.6333
# Epoch 9/20
# 10/10 [==============================] - 5s 482ms/step - loss: 1.0150 - accuracy: 0.6600 - val_loss: 1.3244 - val_accuracy: 0.6000
# Epoch 10/20
# 10/10 [==============================] - 4s 433ms/step - loss: 1.0240 - accuracy: 0.6700 - val_loss: 0.9467 - val_accuracy: 0.6333
# Epoch 11/20
# 10/10 [==============================] - 3s 306ms/step - loss: 0.7512 - accuracy: 0.7850 - val_loss: 1.0984 - val_accuracy: 0.7167
# Epoch 12/20
# 10/10 [==============================] - 3s 305ms/step - loss: 0.7963 - accuracy: 0.7650 - val_loss: 0.7688 - val_accuracy: 0.7667
# Epoch 13/20
# 10/10 [==============================] - 4s 405ms/step - loss: 0.6363 - accuracy: 0.8300 - val_loss: 1.0747 - val_accuracy: 0.7000
# Epoch 14/20
# 10/10 [==============================] - 4s 452ms/step - loss: 0.6789 - accuracy: 0.8000 - val_loss: 0.9576 - val_accuracy: 0.6833
# Epoch 15/20
# 10/10 [==============================] - 4s 342ms/step - loss: 0.6177 - accuracy: 0.8000 - val_loss: 0.8925 - val_accuracy: 0.6667
# Epoch 16/20
# 10/10 [==============================] - 5s 485ms/step - loss: 0.5896 - accuracy: 0.8200 - val_loss: 1.0217 - val_accuracy: 0.6667
# Epoch 17/20
# 10/10 [==============================] - 3s 311ms/step - loss: 0.6600 - accuracy: 0.8100 - val_loss: 0.7612 - val_accuracy: 0.7167
# Epoch 18/20
# 10/10 [==============================] - 5s 445ms/step - loss: 0.4950 - accuracy: 0.8500 - val_loss: 0.9877 - val_accuracy: 0.6333
# Epoch 19/20
# 10/10 [==============================] - 5s 512ms/step - loss: 0.4274 - accuracy: 0.8777 - val_loss: 0.8480 - val_accuracy: 0.7000
# Epoch 20/20
# 10/10 [==============================] - 4s 435ms/step - loss: 0.4718 - accuracy: 0.8850 - val_loss: 0.9045 - val_accuracy: 0.7000

# %%
# %matplotlib inline

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc, label='Training')
plt.plot  ( epochs, val_acc, label='Validation')
plt.title ('Training and validation accuracy')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss, label='Training')
plt.plot  ( epochs, val_loss, label='Validation')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(75,75),
    class_mode='categorical',
    batch_size=20
)
# Out:
# Found 207 images belonging to 10 classes.

# %%
results = model_2.evaluate(test_generator)
# Out:
# 11/11 [==============================] - 3s 234ms/step - loss: 0.8057 - accuracy: 0.7198

# %%
path = "E:/project plan/indonesian food/test_dir/Bika Ambon/188_12c5a680.jpg"
img = image.load_img(path, target_size=(75,75))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
labels = train_generator.class_indices.keys()
images = np.vstack([x])
predict = model_2.predict(images)[0]
plt.imshow(img)
plt.show()
for (label, p) in zip(labels, predict):
    print("{}: {:.2f}%".format(label, p * 100))
# Out:
# Ayam Betutu: 0.23%
# Bika Ambon: 68.56%
# Empek-Empek: 20.11%
# Gudeg: 1.76%
# Gulai Ikan Patin: 0.48%
# Kue Serabi: 3.20%
# Lumpia: 4.31%
# Mie Aceh: 0.04%
# Rendang: 1.25%
# Soto Banjar: 0.06%

# %%
saved_model = "saved_model"
tf.saved_model.save(model_2, saved_model)
# Out:
# INFO:tensorflow:Assets written to: saved_model\assets

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model)
tflite_model = converter.convert()

with open('model_lite.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
with open('labels.txt', 'w') as f:
    f.write('\n'.join(labels))

# %%
saved_model_path = "model_kuliner.h5"

# Save model h5
model_2.save(saved_model_path)
